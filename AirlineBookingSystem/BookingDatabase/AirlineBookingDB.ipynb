-- %% [markdown]
-- # [dbo].[AdminAccount]

-- %%
USE [AirlineBookingDB]
GO

-- %%
/****** Object:  Table [dbo].[AdminAccount]    Script Date: 06/09/2025 9:40:18 pm ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AdminAccount](
	[fullname] [varchar](99) NOT NULL,
	[admin_name] [varchar](99) NOT NULL,
	[admin_password] [varchar](99) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FlightDetails]

-- %%
/****** Object:  Table [dbo].[FlightDetails]    Script Date: 06/09/2025 9:40:19 pm ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FlightDetails](
	[flight_code] [varchar](20) NULL,
	[travel] [varchar](50) NULL,
	[depart_date] [date] NULL,
	[depart_from] [varchar](99) NULL,
	[arriv_to] [varchar](99) NULL,
	[IsArchived] [bit] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PassengerDetails]

-- %%
/****** Object:  Table [dbo].[PassengerDetails]    Script Date: 06/09/2025 9:40:19 pm ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PassengerDetails](
	[book_ref] [varchar](50) NOT NULL,
	[book_date] [date] NOT NULL,
	[firstname] [varchar](50) NOT NULL,
	[middlename] [varchar](50) NOT NULL,
	[lastname] [varchar](50) NOT NULL,
	[gender] [varchar](50) NULL,
	[nationality] [varchar](50) NULL,
	[contact_no] [bigint] NULL,
	[departure_from] [varchar](99) NULL,
	[arrival_to] [varchar](99) NULL,
	[departure_date] [date] NULL,
	[seat_no] [varchar](20) NULL,
	[travel_class] [varchar](50) NULL,
	[base_fare] [int] NULL,
	[tax] [int] NULL,
	[total_amount] [int] NULL,
	[IsCancelled] [bit] NULL,
	[IsArchived] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[book_ref] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PaymentDetails]

-- %%
/****** Object:  Table [dbo].[PaymentDetails]    Script Date: 06/09/2025 9:40:19 pm ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PaymentDetails](
	[book_ref] [varchar](50) NULL,
	[payment_method] [varchar](50) NULL,
	[account_name] [varchar](50) NOT NULL,
	[account_num] [bigint] NULL,
	[amount] [float] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserAccount]

-- %%
/****** Object:  Table [dbo].[UserAccount]    Script Date: 06/09/2025 9:40:19 pm ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserAccount](
	[fullname] [varchar](99) NULL,
	[username] [varchar](99) NULL,
	[password] [varchar](99) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__FlightDet__IsArc__607251E5]

-- %%
ALTER TABLE [dbo].[FlightDetails] ADD  DEFAULT ((0)) FOR [IsArchived]
GO

-- %% [markdown]
-- # [DF__Passenger__IsCan__4D5F7D71]

-- %%
ALTER TABLE [dbo].[PassengerDetails] ADD  DEFAULT ((0)) FOR [IsCancelled]
GO

-- %% [markdown]
-- # [DF__Passenger__IsArc__4E53A1AA]

-- %%
ALTER TABLE [dbo].[PassengerDetails] ADD  DEFAULT ((0)) FOR [IsArchived]
GO

-- %% [markdown]
-- # [FK__PaymentDe__book___04E4BC85]

-- %%
ALTER TABLE [dbo].[PaymentDetails]  WITH CHECK ADD FOREIGN KEY([book_ref])
REFERENCES [dbo].[PassengerDetails] ([book_ref])
GO
